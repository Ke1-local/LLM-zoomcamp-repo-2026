# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
client = Anthropic()

# %%
from rag_helper import RAGBase

assistant = RAGBase(sqlite_index, client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes, you can still join the course! \n\nHowever, there\'s an important detail: **if you want to receive a certificate, you need to submit your project while submissions are still being accepted.** This is because certificates are only awarded when you complete the course with a "live" cohort and participate in peer-reviewing capstone projects.\n\nYou can start learning and submitting homework right away without needing a confirmation email—registration is not checked against any official list.'

# %%
sqlite_index.close()
